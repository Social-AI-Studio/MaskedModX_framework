# %% [markdown]
# # Mount drive

# %%
from google.colab import drive
drive.mount("/content/drive")

# %% [markdown]
# # Import libraries

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# install.packages("remotes")
# remotes::install_github("kgwet/irrCAC@90c0d2f5cf7a94f42cc144a53028ab4a95d0f877")
# remotes::install_github("kgwet/pairedCAC@ca6431c59633291a459c8c9a7523c63fc9c43e22")
# remotes::install_version("ggplot2", version="4.0.1")
# remotes::install_version("patchwork", version="1.3.2")
# remotes::install_version("tidyverse", version="2.0.0")
# library(irrCAC)
# library(pairedCAC)
# library(ggplot2)
# library(patchwork)
# library(tidyverse)

# %% [markdown]
# # Import data

# %% [markdown]
# ### SBIC

# %%
# %%R
# SBIC_v2_tst <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC.v2.tst.csv", stringsAsFactors = FALSE)

# %%
# %%R
# SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct <- SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct[, !grepl("mixed", colnames(SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct))]
# SBIC_offensiveYN_mixed_race_main_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_mixed_race_main_llama_v3p3_70b_instruct.csv")
# SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected <- full_join(
#     SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct,
#     SBIC_offensiveYN_mixed_race_main_llama_v3p3_70b_instruct,
#     by = c("post", "offensiveYN_mode")
# )
# SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct[, grep("response_text", names(SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct))] <- lapply(SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct[, grep("response_text", names(SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct))], function(x) gsub(".", "", x, fixed = TRUE))
#
# SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct_finetuned <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct_finetuned.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned <- SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned[, !grepl("mixed", colnames(SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned))]
# SBIC_offensiveYN_mixed_race_main_llama_v3p3_70b_instruct_finetuned <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_mixed_race_main_llama_v3p3_70b_instruct_finetuned.csv")
# SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected <- full_join(
#     SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned,
#     SBIC_offensiveYN_mixed_race_main_llama_v3p3_70b_instruct_finetuned,
#     by = c("post", "offensiveYN_mode")
# )
#
# SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507 <- SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507[, !grepl("mixed", colnames(SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507))]
# SBIC_offensiveYN_mixed_race_main_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_mixed_race_main_qwen3_30b_a3b_instruct_2507.csv")
# SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected <- full_join(
#     SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507,
#     SBIC_offensiveYN_mixed_race_main_qwen3_30b_a3b_instruct_2507,
#     by = c("post", "offensiveYN_mode")
# )
#
# SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507_finetuned <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507_finetuned.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned <- SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned[, !grepl("mixed", colnames(SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned))]
# SBIC_offensiveYN_mixed_race_main_qwen3_30b_a3b_instruct_2507_finetuned <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_mixed_race_main_qwen3_30b_a3b_instruct_2507_finetuned.csv")
# SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected <- full_join(
#     SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned,
#     SBIC_offensiveYN_mixed_race_main_qwen3_30b_a3b_instruct_2507_finetuned,
#     by = c("post", "offensiveYN_mode")
# )
#
# SBIC_offensiveYN_gender_identity_personas_kimi_k2_instruct_0905 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_personas_kimi_k2_instruct_0905.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_kimi_k2_instruct_0905 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_kimi_k2_instruct_0905.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_political_leaning_personas_kimi_k2_instruct_0905 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_political_leaning_personas_kimi_k2_instruct_0905.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_sexual_orientation_personas_kimi_k2_instruct_0905 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_sexual_orientation_personas_kimi_k2_instruct_0905.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905 <- SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905[, !grepl("mixed", colnames(SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905))]
# SBIC_offensiveYN_mixed_race_main_kimi_k2_instruct_0905 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_mixed_race_main_kimi_k2_instruct_0905.csv")
# SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected <- full_join(
#     SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905,
#     SBIC_offensiveYN_mixed_race_main_kimi_k2_instruct_0905,
#     by = c("post", "offensiveYN_mode")
# )
# SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected[, grep("response_text", names(SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected))] <- lapply(SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected[, grep("response_text", names(SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected))], function(x) gsub("Incomprensible", "Incomprehensible", x, fixed = TRUE))

# %%
# %%R
# man <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/man.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_man_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_man_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_man_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_man_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
#
# woman <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/woman.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_woman_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_woman_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_woman_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_woman_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
#
# asian <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/asian.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_asian_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_asian_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_asian_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_asian_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
#
# black <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/black.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_black_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_black_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_black_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_black_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
#
# hisp <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/hisp.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_hisp_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_hisp_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_hisp_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_hisp_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
#
# white <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/white.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_white_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_white_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_white_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_white_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
#
# mixed_race <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/mixed.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_mixed_race_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_mixed_race_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_mixed_race_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_mixed_race_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
#
# cons <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/cons.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_cons_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_cons_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_cons_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_cons_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
#
# liberal <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/liberal.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_liberal_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_liberal_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_liberal_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_liberal_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
#
# libert <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/libert.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_libert_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_libert_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_libert_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_libert_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
#
# mod_cons <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/mod_cons.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_mod_cons_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_mod_cons_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_mod_cons_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_mod_cons_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
#
# mod_liberal <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/mod_liberal.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_mod_liberal_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_mod_liberal_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_mod_liberal_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_mod_liberal_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)
#
# independent <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/other.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_independent_qwen3_30b_a3b_instruct_2507 <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_independent_qwen3_30b_a3b_instruct_2507.csv", stringsAsFactors = FALSE)
# SBIC_offensiveYN_independent_llama_v3p3_70b_instruct <- read.csv("/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_independent_llama_v3p3_70b_instruct.csv", stringsAsFactors = FALSE)

# %% [markdown]
# # Full join of dataframes

# %%
# %%R
# SBIC_offensiveYN_llama_v3p3_70b_instruct <- list(
#     SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct,
#     SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct,
#     SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct,
#     SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected,
#     SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct
# ) %>% reduce(full_join, by = c("post", "offensiveYN_mode"))
#
# SBIC_offensiveYN_llama_v3p3_70b_instruct_finetuned <- list(
#     SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct_finetuned,
#     SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned,
#     SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned,
#     SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected,
#     SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned
# ) %>% reduce(full_join, by = c("post", "offensiveYN_mode"))
#
# SBIC_offensiveYN_qwen3_30b_a3b_instruct_2507 <- list(
#     SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507,
#     SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507,
#     SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507,
#     SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected,
#     SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507
# ) %>% reduce(full_join, by = c("post", "offensiveYN_mode"))
#
# SBIC_offensiveYN_qwen3_30b_a3b_instruct_2507_finetuned <- list(
#     SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507_finetuned,
#     SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned,
#     SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned,
#     SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected,
#     SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned
# ) %>% reduce(full_join, by = c("post", "offensiveYN_mode"))
#
# SBIC_offensiveYN_kimi_k2_instruct_0905 <- list(
#     SBIC_offensiveYN_gender_identity_personas_kimi_k2_instruct_0905,
#     SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_kimi_k2_instruct_0905,
#     SBIC_offensiveYN_political_leaning_personas_kimi_k2_instruct_0905,
#     SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected,
#     SBIC_offensiveYN_sexual_orientation_personas_kimi_k2_instruct_0905
# ) %>% reduce(full_join, by = c("post", "offensiveYN_mode"))

# %% [markdown]
# # Subsetting distinct SBIC posts where all available annotations identify the post as offensive and the target as (black or woman)

# %%
# %%R
# black_targeted <- SBIC_v2_tst %>%
#     group_by(post) %>%
#     filter(
#         all(offensiveYN == 1),
#         all(str_detect(targetMinority, "black folks"))
#     ) %>%
#     ungroup() %>%
#     distinct(post)
# women_targeted <- SBIC_v2_tst %>%
#     group_by(post) %>%
#     filter(
#         all(offensiveYN == 1),
#         all(str_detect(targetMinority, "^women$|^women,"))
#     ) %>%
#     ungroup() %>%
#     distinct(post)

# %% [markdown]
# # Propagation of baseline_response_text column for SBIC

# %%
# %%R
# SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected$baseline_response_text
# SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected$baseline_response_text
# SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected$baseline_response_text
# SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected$baseline_response_text
#
# SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct_finetuned$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected$baseline_response_text
# SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected$baseline_response_text
# SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected$baseline_response_text
# SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected$baseline_response_text
#
# SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected$baseline_response_text
# SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected$baseline_response_text
# SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected$baseline_response_text
# SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected$baseline_response_text
#
# SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507_finetuned$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected$baseline_response_text
# SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected$baseline_response_text
# SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected$baseline_response_text
# SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected$baseline_response_text
#
# SBIC_offensiveYN_gender_identity_personas_kimi_k2_instruct_0905$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected$baseline_response_text
# SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_kimi_k2_instruct_0905$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected$baseline_response_text
# SBIC_offensiveYN_political_leaning_personas_kimi_k2_instruct_0905$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected$baseline_response_text
# SBIC_offensiveYN_sexual_orientation_personas_kimi_k2_instruct_0905$baseline_response_text <- SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected$baseline_response_text

# %% [markdown]
# # Merging LLM outputs with subsets of distinct SBIC posts where all available annotations identify the post as offensive and the target as (black or woman)

# %%
# %%R
# black_targeted_subset_SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected <- black_targeted %>%
#     left_join(SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected, by = "post")
# black_targeted_subset_SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected <- black_targeted %>%
#     left_join(SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected, by = "post")
# black_targeted_subset_SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected <- black_targeted %>%
#     left_join(SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected, by = "post")
# black_targeted_subset_SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected <- black_targeted %>%
#     left_join(SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected, by = "post")
# black_targeted_subset_SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected <- black_targeted %>%
#     left_join(SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected, by = "post")
#
# women_targeted_subset_SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct <- women_targeted %>%
#     left_join(SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct, by = "post")
# women_targeted_subset_SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct_finetuned <- women_targeted %>%
#     left_join(SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct_finetuned, by = "post")
# women_targeted_subset_SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507 <- women_targeted %>%
#     left_join(SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507, by = "post")
# women_targeted_subset_SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507_finetuned <- women_targeted %>%
#     left_join(SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507_finetuned, by = "post")
# women_targeted_subset_SBIC_offensiveYN_gender_identity_personas_kimi_k2_instruct_0905 <- women_targeted %>%
#     left_join(SBIC_offensiveYN_gender_identity_personas_kimi_k2_instruct_0905, by = "post")
#
# women_targeted_subset_SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct <- women_targeted %>%
#     left_join(SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct, by = "post")
# women_targeted_subset_SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned <- women_targeted %>%
#     left_join(SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned, by = "post")
# women_targeted_subset_SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507 <- women_targeted %>%
#     left_join(SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507, by = "post")
# women_targeted_subset_SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned <- women_targeted %>%
#     left_join(SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned, by = "post")
# women_targeted_subset_SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_kimi_k2_instruct_0905 <- women_targeted %>%
#     left_join(SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_kimi_k2_instruct_0905, by = "post")
#
# women_targeted_subset_SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct <- women_targeted %>%
#     left_join(SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct, by = "post")
# women_targeted_subset_SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned <- women_targeted %>%
#     left_join(SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned, by = "post")
# women_targeted_subset_SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507 <- women_targeted %>%
#     left_join(SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507, by = "post")
# women_targeted_subset_SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned <- women_targeted %>%
#     left_join(SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned, by = "post")
# women_targeted_subset_SBIC_offensiveYN_sexual_orientation_personas_kimi_k2_instruct_0905 <- women_targeted %>%
#     left_join(SBIC_offensiveYN_sexual_orientation_personas_kimi_k2_instruct_0905, by = "post")

# %% [markdown]
# # Computation of recall

# %%
# %%R
# fraction_yes <- function(df) {
#     cols <- grep("response_text", names(df), value = TRUE)
#     fraction <- sapply(df[cols], function(x) {
#         sum(tolower(x) == "yes") / nrow(df)
#     })
#     print(fraction)
# }

# %%
# %%R
# fraction_yes(black_targeted_subset_SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected)
# print("----------------------------------------------------------------------")
# fraction_yes(black_targeted_subset_SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected)
# print("----------------------------------------------------------------------")
# fraction_yes(black_targeted_subset_SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected)
# print("----------------------------------------------------------------------")
# fraction_yes(black_targeted_subset_SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected)
# print("----------------------------------------------------------------------")
# fraction_yes(black_targeted_subset_SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected)
# print("----------------------------------------------------------------------")

# %%
# %%R
# fraction_yes(women_targeted_subset_SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct)
# print("----------------------------------------------------------------------")
# fraction_yes(women_targeted_subset_SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct_finetuned)
# print("----------------------------------------------------------------------")
# fraction_yes(women_targeted_subset_SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507)
# print("----------------------------------------------------------------------")
# fraction_yes(women_targeted_subset_SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507_finetuned)
# print("----------------------------------------------------------------------")
# fraction_yes(women_targeted_subset_SBIC_offensiveYN_gender_identity_personas_kimi_k2_instruct_0905)
# print("----------------------------------------------------------------------")

# %%
# %%R
# fraction_yes(women_targeted_subset_SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct)
# print("----------------------------------------------------------------------")
# fraction_yes(women_targeted_subset_SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned)
# print("----------------------------------------------------------------------")
# fraction_yes(women_targeted_subset_SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507)
# print("----------------------------------------------------------------------")
# fraction_yes(women_targeted_subset_SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned)
# print("----------------------------------------------------------------------")
# fraction_yes(women_targeted_subset_SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_kimi_k2_instruct_0905)
# print("----------------------------------------------------------------------")

# %%
# %%R
# fraction_yes(women_targeted_subset_SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct)
# print("----------------------------------------------------------------------")
# fraction_yes(women_targeted_subset_SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned)
# print("----------------------------------------------------------------------")
# fraction_yes(women_targeted_subset_SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507)
# print("----------------------------------------------------------------------")
# fraction_yes(women_targeted_subset_SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned)
# print("----------------------------------------------------------------------")
# fraction_yes(women_targeted_subset_SBIC_offensiveYN_sexual_orientation_personas_kimi_k2_instruct_0905)
# print("----------------------------------------------------------------------")

# %% [markdown]
# # Computation and interpretation of Krippendorff's alpha coefficients

# %%
# %%R
# compute_alpha <- function(df, reference) {
#     for (i in seq_along(colnames(df))) {
#         if (colnames(df)[i] != reference && grepl("response_text", colnames(df)[i])) {
#             print(colnames(df)[i])
#             # Retrieve and interpret Krippendorff's alpha values. via
#             # https://cran.r-project.org/web/packages/irrCAC/vignettes/
#             # benchmarking.html
#             a <- krippen.alpha.raw(ratings = df[, c(reference, colnames(df)[i])], weights = "unweighted", categ.labels = c("Incomprehensible", "Maybe", "No", "Yes"), conflev = .95)
#             print(a$est)
#             print(a$categories)
#             print(landis.koch.bf(a$est$coeff.val, a$est$coeff.se))
#         }
#     }
# }

# %% [markdown]
# ### Computation of Krippendorff's alpha coefficients between the personas and the no-persona defaults

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_llama_v3p3_70b_instruct, "baseline_response_text")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_llama_v3p3_70b_instruct_finetuned, "baseline_response_text")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_qwen3_30b_a3b_instruct_2507, "baseline_response_text")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_qwen3_30b_a3b_instruct_2507_finetuned, "baseline_response_text")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_kimi_k2_instruct_0905, "baseline_response_text")

# %% [markdown]
# ### Computation of Krippendorff's alpha coefficients between the personas and human annotations belonging to the same sociodemographic

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_man_llama_v3p3_70b_instruct, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# compute_alpha(SBIC_offensiveYN_man_qwen3_30b_a3b_instruct_2507, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# man %>%
#     left_join(
#         SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct %>%
#         select(post, contains("a_man")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# man %>%
#     left_join(
#         SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct_finetuned %>%
#         select(post, contains("a_man")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# man %>%
#     left_join(
#         SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507 %>%
#         select(post, contains("a_man")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# man %>%
#     left_join(
#         SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507_finetuned %>%
#         select(post, contains("a_man")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# man %>%
#     left_join(
#         SBIC_offensiveYN_gender_identity_personas_kimi_k2_instruct_0905 %>%
#         select(post, contains("a_man")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_woman_llama_v3p3_70b_instruct, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# compute_alpha(SBIC_offensiveYN_woman_qwen3_30b_a3b_instruct_2507, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# woman %>%
#     left_join(
#         SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct %>%
#         select(post, contains("a_woman")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# woman %>%
#     left_join(
#         SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct_finetuned %>%
#         select(post, contains("a_woman")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# woman %>%
#     left_join(
#         SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507 %>%
#         select(post, contains("a_woman")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# woman %>%
#     left_join(
#         SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507_finetuned %>%
#         select(post, contains("a_woman")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# woman %>%
#     left_join(
#         SBIC_offensiveYN_gender_identity_personas_kimi_k2_instruct_0905 %>%
#         select(post, contains("a_woman")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_black_llama_v3p3_70b_instruct, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# compute_alpha(SBIC_offensiveYN_black_qwen3_30b_a3b_instruct_2507, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# black %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected %>%
#         select(post, contains("a_Black")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# black %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected %>%
#         select(post, contains("a_Black")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# black %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected %>%
#         select(post, contains("a_Black")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# black %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected %>%
#         select(post, contains("a_Black")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# black %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected %>%
#         select(post, contains("a_Black")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_asian_llama_v3p3_70b_instruct, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# compute_alpha(SBIC_offensiveYN_asian_qwen3_30b_a3b_instruct_2507, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# asian %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected %>%
#         select(post, contains("an_Asian")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# asian %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected %>%
#         select(post, contains("an_Asian")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# asian %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected %>%
#         select(post, contains("an_Asian")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# asian %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected %>%
#         select(post, contains("an_Asian")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# asian %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected %>%
#         select(post, contains("an_Asian")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_hisp_llama_v3p3_70b_instruct, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# compute_alpha(SBIC_offensiveYN_hisp_qwen3_30b_a3b_instruct_2507, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# hisp %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected %>%
#         select(post, contains("a_Hispanic")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# hisp %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected %>%
#         select(post, contains("a_Hispanic")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# hisp %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected %>%
#         select(post, contains("a_Hispanic")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# hisp %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected %>%
#         select(post, contains("a_Hispanic")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# hisp %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected %>%
#         select(post, contains("a_Hispanic")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_white_llama_v3p3_70b_instruct, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# compute_alpha(SBIC_offensiveYN_white_qwen3_30b_a3b_instruct_2507, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# white %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected %>%
#         select(post, contains("a_White")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# white %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected %>%
#         select(post, contains("a_White")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# white %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected %>%
#         select(post, contains("a_White")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# white %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected %>%
#         select(post, contains("a_White")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# white %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected %>%
#         select(post, contains("a_White")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_mixed_race_llama_v3p3_70b_instruct, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# compute_alpha(SBIC_offensiveYN_mixed_race_qwen3_30b_a3b_instruct_2507, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# mixed_race %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected %>%
#         select(post, contains("of_mixed_race")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# mixed_race %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected %>%
#         select(post, contains("of_mixed_race")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# mixed_race %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected %>%
#         select(post, contains("of_mixed_race")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# mixed_race %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected %>%
#         select(post, contains("of_mixed_race")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# mixed_race %>%
#     left_join(
#         SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected %>%
#         select(post, contains("of_mixed_race")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_cons_llama_v3p3_70b_instruct, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# compute_alpha(SBIC_offensiveYN_cons_qwen3_30b_a3b_instruct_2507, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# cons %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct %>%
#         select(post, contains("a_conservative")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# cons %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned %>%
#         select(post, contains("a_conservative")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# cons %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507 %>%
#         select(post, contains("a_conservative")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# cons %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned %>%
#         select(post, contains("a_conservative")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# cons %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_kimi_k2_instruct_0905 %>%
#         select(post, contains("a_conservative")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_mod_cons_llama_v3p3_70b_instruct, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# compute_alpha(SBIC_offensiveYN_mod_cons_qwen3_30b_a3b_instruct_2507, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# mod_cons %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct %>%
#         select(post, contains("a_moderate_conservative")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# mod_cons %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned %>%
#         select(post, contains("a_moderate_conservative")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# mod_cons %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507 %>%
#         select(post, contains("a_moderate_conservative")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# mod_cons %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned %>%
#         select(post, contains("a_moderate_conservative")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# mod_cons %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_kimi_k2_instruct_0905 %>%
#         select(post, contains("a_moderate_conservative")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_mod_liberal_llama_v3p3_70b_instruct, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# compute_alpha(SBIC_offensiveYN_mod_liberal_qwen3_30b_a3b_instruct_2507, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# mod_liberal %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct %>%
#         select(post, contains("a_moderate_liberal")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# mod_liberal %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned %>%
#         select(post, contains("a_moderate_liberal")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# mod_liberal %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507 %>%
#         select(post, contains("a_moderate_liberal")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# mod_liberal %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned %>%
#         select(post, contains("a_moderate_liberal")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# mod_liberal %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_kimi_k2_instruct_0905 %>%
#         select(post, contains("a_moderate_liberal")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_liberal_llama_v3p3_70b_instruct, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# compute_alpha(SBIC_offensiveYN_liberal_qwen3_30b_a3b_instruct_2507, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# liberal %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct %>%
#         select(post, contains("a_liberal")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# liberal %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned %>%
#         select(post, contains("a_liberal")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# liberal %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507 %>%
#         select(post, contains("a_liberal")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# liberal %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned %>%
#         select(post, contains("a_liberal")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# liberal %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_kimi_k2_instruct_0905 %>%
#         select(post, contains("a_liberal")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_libert_llama_v3p3_70b_instruct, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# compute_alpha(SBIC_offensiveYN_libert_qwen3_30b_a3b_instruct_2507, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# libert %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct %>%
#         select(post, contains("a_libertarian")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# libert %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned %>%
#         select(post, contains("a_libertarian")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# libert %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507 %>%
#         select(post, contains("a_libertarian")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# libert %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned %>%
#         select(post, contains("a_libertarian")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# libert %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_kimi_k2_instruct_0905 %>%
#         select(post, contains("a_libertarian")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_alpha(SBIC_offensiveYN_independent_llama_v3p3_70b_instruct, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# compute_alpha(SBIC_offensiveYN_independent_qwen3_30b_a3b_instruct_2507, "offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# independent %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct %>%
#         select(post, contains("independent")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# independent %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned %>%
#         select(post, contains("independent")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# independent %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507 %>%
#         select(post, contains("independent")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# independent %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned %>%
#         select(post, contains("independent")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")
# independent %>%
#     left_join(
#         SBIC_offensiveYN_political_leaning_personas_kimi_k2_instruct_0905 %>%
#         select(post, contains("independent")),
#         by = "post"
#     ) %>%
#     compute_alpha("offensiveYN_unanimous")
# print("----------------------------------------------------------------------")

# %% [markdown]
# # Computation of RIS

# %%
# %%R
# compute_RIS <- function(df) {
#     patterns <- c(
#         "persona_instruction1" = "persona_instruction1_response_text",
#         "persona_instruction2" = "persona_instruction2_response_text",
#         "persona_instruction3" = "persona_instruction3_response_text"
#     )
#     for (grp in names(patterns)) {
#         cols <- grep(patterns[grp], names(df), value = TRUE)
#         p_values <- apply(combn(cols, 2), 2, function(pair) {
#             ttest.alpha(
#                 df[, c("baseline_response_text", pair[1])],
#                 df[, c("baseline_response_text", pair[2])]
#             )$test$p.value
#         })
#         print(grp)
#         print(mean(p_values < 0.05))
#     }
# }

# %%
# %%R
# compute_RIS(SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct_finetuned)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507_finetuned)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_gender_identity_personas_kimi_k2_instruct_0905)
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_RIS(SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_kimi_k2_instruct_0905)
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_RIS(SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_political_leaning_personas_kimi_k2_instruct_0905)
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_RIS(SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_sexual_orientation_personas_kimi_k2_instruct_0905)
# print("----------------------------------------------------------------------")

# %%
# %%R
# compute_RIS(SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected)
# print("----------------------------------------------------------------------")
# compute_RIS(SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected)
# print("----------------------------------------------------------------------")

# %% [markdown]
# # Generation of plots

# %%
# %%R
# persona_map <- c(
#     "a_man" = "a man",
#     "a_woman" = "a woman",
#     "a_transgender_man" = "a transgender man",
#     "a_transgender_woman" = "a transgender woman",
#     "a_non_binary_individual" = "a non-binary individual",
#     "a_heterosexual_straight_man" = "a heterosexual/straight man",
#     "a_heterosexual_straight_woman" = "a heterosexual/straight woman",
#     "a_gay_man" = "a gay man",
#     "a_lesbian_woman" = "a lesbian woman",
#     "a_bisexual_man" = "a bisexual man",
#     "a_bisexual_woman" = "a bisexual woman",
#     "a_conservative" = "a conservative",
#     "a_moderate_conservative" = "a moderate conservative",
#     "a_moderate_liberal" = "a moderate liberal",
#     "a_liberal_progressive" = "a liberal/progressive",
#     "a_libertarian" = "a libertarian",
#     "an_independent_or_an_individual_with_a_non_mainstream_political_leaning" = "an independent or ...",
#     "an_Asian_Asian_American_individual" = "an Asian/Asian American individual",
#     "a_Black_African_American_individual" = "a Black/African American individual",
#     "a_Hispanic_Latinx_individual" = "a Hispanic/Latinx individual",
#     "a_White_Caucasian_individual" = "a White/Caucasian individual",
#     "a_Native_Hawaiian_Pacific_Islander_individual" = "a Native Hawaiian/Pacific Islander individual",
#     "a_Native_American_First_Nations_individual" = "a Native American/First Nations individual",
#     "an_individual_who_is_of_mixed_race_or_of_a_race_ethnicity_not_otherwise_listed" = "an individual of mixed-race or ...",
#     "a_heterosexual_straight_individual" = "a heterosexual/straight individual",
#     "a_gay_lesbian_individual" = "a gay/lesbian individual",
#     "a_bisexual_individual" = "a bisexual individual"
# )
#
# generate_plot <- function(df, outputfile) {
#     metadata <- list(
#         list(name = "persona_instruction1",
#              pattern = "persona_instruction1_response_text",
#              subplot_title = "(a) Instruction 1"),
#         list(name = "persona_instruction2",
#              pattern = "persona_instruction2_response_text",
#              subplot_title = "(b) Instruction 2"),
#         list(name = "persona_instruction3",
#              pattern = "persona_instruction3_response_text",
#              subplot_title = "(c) Instruction 3")
#     )
#     plot_list <- list()
#     for (grp in metadata) {
#         personas <- sort(grep(grp$pattern, names(df), value = TRUE))
#         pairs <- combn(personas, 2, simplify = FALSE)
#         ttest_results <- do.call(rbind, lapply(pairs, function(pair) {
#             tst <- ttest.alpha(
#                 df[, c(pair[1], "baseline_response_text")],
#                 df[, c(pair[2], "baseline_response_text")],
#                 weights = "unweighted",
#                 conflev = 0.95
#             )$test
#             data.frame(persona1 = pair[1], persona2 = pair[2], coeff_diff = tst$coeff.diff, p_value = tst$p.value)
#         }))
#         ttest_results$persona1_label <- unname(persona_map[sub("_in_the_United_States", "", sub(paste0("_", grp$pattern), "", ttest_results$persona1, fixed = TRUE), fixed = TRUE)])
#         ttest_results$persona2_label <- unname(persona_map[sub("_in_the_United_States", "", sub(paste0("_", grp$pattern), "", ttest_results$persona2, fixed = TRUE), fixed = TRUE)])
#         ttest_results$persona1_factor <- factor(ttest_results$persona1_label, levels = sort(unique(c(ttest_results$persona1_label, ttest_results$persona2_label))))
#         ttest_results$persona2_factor <- factor(ttest_results$persona2_label, levels = sort(unique(c(ttest_results$persona1_label, ttest_results$persona2_label))))
#         ttest_results$legend_label <- ifelse(ttest_results$p_value < 0.05 & ttest_results$coeff_diff < 0, "Krippendorff's alpha between baseline and x-axis persona is significantly higher", ifelse(ttest_results$p_value < 0.05 & ttest_results$coeff_diff > 0, "Krippendorff's alpha between baseline and y-axis persona is significantly higher", "nonsignificant"))
#         g <- ggplot(ttest_results, aes(persona1_factor, persona2_factor, fill = legend_label)) +
#             geom_tile(color = "white", linewidth = 1, show.legend = TRUE) +
#             scale_fill_manual(
#                 values = c(
#                     "Krippendorff's alpha between baseline and x-axis persona is significantly higher" = "#840032",
#                     "Krippendorff's alpha between baseline and y-axis persona is significantly higher" = "#e59500",
#                     "nonsignificant" = "#002642"
#                 ),
#                 limits = c(
#                     "Krippendorff's alpha between baseline and x-axis persona is significantly higher",
#                     "Krippendorff's alpha between baseline and y-axis persona is significantly higher",
#                     "nonsignificant"
#                 ),
#                 name = "Paired T-test Results",
#                 drop = FALSE
#             ) +
#             labs(
#                 title = grp$subplot_title,
#                 x = NULL,
#                 y = NULL
#             ) +
#             coord_fixed() +
#             theme_minimal(base_family = "Helvetica", base_size = 42) +
#             theme(
#                 axis.text.x = element_text(angle = 30, hjust = 1),
#                 plot.title = element_text(hjust = 0.5, margin = margin(b = 3, unit = "pt")),
#                 panel.grid.major = element_line(linewidth = 0.5, color = "grey80")
#             )
#             if (grp$name == "persona_instruction1") {
#                 g <- g + theme(
#                     plot.margin = margin(t = 0, r = 25, b = 0, l = 0, unit = "pt")
#                 )
#             } else if (grp$name == "persona_instruction3") {
#                 g <- g + theme(
#                     axis.title.y = element_blank(),
#                     axis.text.y = element_blank(),
#                     plot.margin = margin(t = 0, r = 0, b = 0, l = 25, unit = "pt")
#                 )
#             } else {
#                 g <- g + theme(
#                     axis.title.y = element_blank(),
#                     axis.text.y = element_blank(),
#                     plot.margin = margin(t = 0, r = 25, b = 0, l = 25, unit = "pt")
#                 )
#             }
#         plot_list[[grp$name]] <- g
#     }
#     # Wrap plots. via
#     # https://stackoverflow.com/questions/66688668/automatically-assemble-plots-for-patchwork-from-a-list-of-ggplots#comment117887198_66688668
#     aggregated_plot <- wrap_plots(plot_list, nrow = 1, guides = "collect") & theme(
#         text = element_text(family = "Helvetica", size = 42),
#         legend.title = element_text(margin = margin(b = 3, unit = "pt")),
#         legend.position = "bottom",
#         legend.justification = 0,
#         legend.direction = "vertical"
#     )
#     ggsave(
#         outputfile,
#         plot = aggregated_plot,
#         device = cairo_ps,
#         bg = "white",
#         width = 28,
#         height = 14,
#         units = "in"
#     )
# }

# %%
# %%R
# generate_plot(SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct.eps")
# generate_plot(SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct_finetuned, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct_finetuned.eps")
# generate_plot(SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507.eps")
# generate_plot(SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507_finetuned, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507_finetuned.eps")
# generate_plot(SBIC_offensiveYN_gender_identity_personas_kimi_k2_instruct_0905, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_personas_kimi_k2_instruct_0905.eps")
#
# generate_plot(SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct.eps")
# generate_plot(SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned.eps")
# generate_plot(SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507.eps")
# generate_plot(SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned.eps")
# generate_plot(SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_kimi_k2_instruct_0905, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_gender_identity_x_sexual_orientation_personas_kimi_k2_instruct_0905.eps")
#
# generate_plot(SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct.eps")
# generate_plot(SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned.eps")
# generate_plot(SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507.eps")
# generate_plot(SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned.eps")
# generate_plot(SBIC_offensiveYN_political_leaning_personas_kimi_k2_instruct_0905, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_political_leaning_personas_kimi_k2_instruct_0905.eps")
#
# generate_plot(SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct.eps")
# generate_plot(SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_sexual_orientation_personas_llama_v3p3_70b_instruct_finetuned.eps")
# generate_plot(SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507.eps")
# generate_plot(SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_sexual_orientation_personas_qwen3_30b_a3b_instruct_2507_finetuned.eps")
# generate_plot(SBIC_offensiveYN_sexual_orientation_personas_kimi_k2_instruct_0905, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_sexual_orientation_personas_kimi_k2_instruct_0905.eps")
#
# generate_plot(SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_corrected.eps")
# generate_plot(SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected.eps")
# generate_plot(SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_corrected.eps")
# generate_plot(SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected.eps")
# generate_plot(SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected, "/content/drive/MyDrive/MaskedModX/SBIC/SBIC_offensiveYN_race_ethnicity_personas_kimi_k2_instruct_0905_corrected.eps")

# %% [markdown]
# # Comparison between specific and composite fine-tuning (paired t-tests)

# %%
# %%R
# specific_vs_composite <- function(df1, df2) {
#     cols <- intersect(names(df1), names(df2)) %>% str_subset("response_text")
#     joined_df <- inner_join(df1, df2, by = "post", suffix = c(".1", ".2"))
#     for (col in cols) {
#         print(col)
#         tst <- ttest.alpha(
#             joined_df[c(paste0(col, ".1"), "offensiveYN_unanimous")],
#             joined_df[c(paste0(col, ".2"), "offensiveYN_unanimous")],
#             weights = "unweighted",
#             conflev = 0.95
#         )$test
#         print(tst)
#     }
# }

# %%
# %%R
# specific_vs_composite(SBIC_offensiveYN_man_llama_v3p3_70b_instruct, SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct_finetuned)
# specific_vs_composite(SBIC_offensiveYN_man_qwen3_30b_a3b_instruct_2507, SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507_finetuned)
# print("----------------------------------------------------------------------")
# specific_vs_composite(SBIC_offensiveYN_woman_llama_v3p3_70b_instruct, SBIC_offensiveYN_gender_identity_personas_llama_v3p3_70b_instruct_finetuned)
# specific_vs_composite(SBIC_offensiveYN_woman_qwen3_30b_a3b_instruct_2507, SBIC_offensiveYN_gender_identity_personas_qwen3_30b_a3b_instruct_2507_finetuned)
# print("----------------------------------------------------------------------")
# specific_vs_composite(SBIC_offensiveYN_asian_llama_v3p3_70b_instruct, SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected)
# specific_vs_composite(SBIC_offensiveYN_asian_qwen3_30b_a3b_instruct_2507, SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected)
# print("----------------------------------------------------------------------")
# specific_vs_composite(SBIC_offensiveYN_black_llama_v3p3_70b_instruct, SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected)
# specific_vs_composite(SBIC_offensiveYN_black_qwen3_30b_a3b_instruct_2507, SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected)
# print("----------------------------------------------------------------------")
# specific_vs_composite(SBIC_offensiveYN_hisp_llama_v3p3_70b_instruct, SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected)
# specific_vs_composite(SBIC_offensiveYN_hisp_qwen3_30b_a3b_instruct_2507, SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected)
# print("----------------------------------------------------------------------")
# specific_vs_composite(SBIC_offensiveYN_white_llama_v3p3_70b_instruct, SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected)
# specific_vs_composite(SBIC_offensiveYN_white_qwen3_30b_a3b_instruct_2507, SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected)
# print("----------------------------------------------------------------------")
# specific_vs_composite(SBIC_offensiveYN_mixed_race_llama_v3p3_70b_instruct, SBIC_offensiveYN_race_ethnicity_personas_llama_v3p3_70b_instruct_finetuned_corrected)
# specific_vs_composite(SBIC_offensiveYN_mixed_race_qwen3_30b_a3b_instruct_2507, SBIC_offensiveYN_race_ethnicity_personas_qwen3_30b_a3b_instruct_2507_finetuned_corrected)
# print("----------------------------------------------------------------------")
# specific_vs_composite(SBIC_offensiveYN_cons_llama_v3p3_70b_instruct, SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned)
# specific_vs_composite(SBIC_offensiveYN_cons_qwen3_30b_a3b_instruct_2507, SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned)
# print("----------------------------------------------------------------------")
# specific_vs_composite(SBIC_offensiveYN_liberal_llama_v3p3_70b_instruct, SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned)
# specific_vs_composite(SBIC_offensiveYN_liberal_qwen3_30b_a3b_instruct_2507, SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned)
# print("----------------------------------------------------------------------")
# specific_vs_composite(SBIC_offensiveYN_libert_llama_v3p3_70b_instruct, SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned)
# specific_vs_composite(SBIC_offensiveYN_libert_qwen3_30b_a3b_instruct_2507, SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned)
# print("----------------------------------------------------------------------")
# specific_vs_composite(SBIC_offensiveYN_mod_cons_llama_v3p3_70b_instruct, SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned)
# specific_vs_composite(SBIC_offensiveYN_mod_cons_qwen3_30b_a3b_instruct_2507, SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned)
# print("----------------------------------------------------------------------")
# specific_vs_composite(SBIC_offensiveYN_mod_liberal_llama_v3p3_70b_instruct, SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned)
# specific_vs_composite(SBIC_offensiveYN_mod_liberal_qwen3_30b_a3b_instruct_2507, SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned)
# print("----------------------------------------------------------------------")
# specific_vs_composite(SBIC_offensiveYN_independent_llama_v3p3_70b_instruct, SBIC_offensiveYN_political_leaning_personas_llama_v3p3_70b_instruct_finetuned)
# specific_vs_composite(SBIC_offensiveYN_independent_qwen3_30b_a3b_instruct_2507, SBIC_offensiveYN_political_leaning_personas_qwen3_30b_a3b_instruct_2507_finetuned)
# print("----------------------------------------------------------------------")
